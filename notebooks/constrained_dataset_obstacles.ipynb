# %%
import gzip
import json
import os
import sys
from typing import List
from matplotlib import pyplot as plt
import argparse
import magnum as mn
import numpy as np
import pandas as pd
import networkx


import habitat_sim
from habitat_sim.physics import MotionType

from habitat.datasets.rearrangement.rearrangement_dataset import RearrangementDatasetV0
from habitat.tasks.rearrangement.rearrangement_task import RearrangementEpisode
from rearrangement.utils.geometry import geodesic_distance

# %%
cd '/srv/flash1/hagrawal9/project/habitat/habitat-api/'
# Out:
# /coc/testnvme/hagrawal9/project/habitat/habitat-api

# %%
# %load_ext autoreload
# %autoreload 2

from rearrangement.utils.dataset import make_cfg, navmesh_settings, init_agent, init_episode_dict, add_goal_details, add_object_details, set_object_on_top_of_surface, settings
from rearrangement.utils.dataset import validate_again, validate_object, graph_validate, euclidean_distance, validate_object_goal_pointnav
from rearrangement.utils.visualization import get_top_down_map_sim
from rearrangement.utils.planner import compute_oracle_pickup_order_sim, compute_l2dist_pickup_order_sim, start_env_episode_distance_sim

# %%
def init_test_scene_new(sim, simple_pathfinder, object_templates, navmesh_settings, num_objects, dist_thresh=5.0, object_obstacles=True):    
    object_positions = []
    goal_positions = []
    object_idxs = []
    goal_idxs = []
    object_template_idxs = []
    
    obj_attr_mgr = sim.get_object_template_manager()
    agent_position = sim.agents[0].scene_node.translation
    
    sim.recompute_navmesh(
        sim.pathfinder, 
        navmesh_settings,
        include_static_objects=object_obstacles
    )
    
    for obj_id in range(num_objects):
        count = 0
        
        object_template_id = np.random.choice(list(object_templates.keys()))
        object_handle = obj_attr_mgr.get_file_template_handles(object_template_id)[0]
        rotation_x = mn.Quaternion.rotation(mn.Deg(-90), mn.Vector3(1.0, 0, 0))
        rotation_y = mn.Quaternion.rotation(mn.Deg(90), mn.Vector3(0.0, 1.0, 0))
        rotation_z = mn.Quaternion.rotation(mn.Deg(0), mn.Vector3(0.0, 0, 1.0))
        # rotation_x1 = mn.Quaternion.rotation(mn.Deg(-45), mn.Vector3(1.0, 0, 0))
        orientation = rotation_z * rotation_y * rotation_x

        object_id = sim.add_object_by_handle(object_handle)
        goal_id = sim.add_object_by_handle(object_handle)

        
        while count < 100:
            
            for oi in range(100):
                object_position = sim.pathfinder.get_random_navigable_point()
                # object_position[1] = agent_position[1]
                # set_object_on_top_of_surface(sim, object_id)
                
                object_dist = sim.pathfinder.distance_to_closest_obstacle(object_position, max_search_radius=2.0)
                ao_geo_dist = geodesic_distance(sim.pathfinder, agent_position, [object_position])
                
                if object_dist > 0.5 and ao_geo_dist < 100:
                    break

            if  oi >= 100: 
                continue 

             
            for oi in range(100):
                goal_position = sim.pathfinder.get_random_navigable_point()
                # goal_position[1] = agent_position[1]
                # set_object_on_top_of_surface(sim, goal_id)
                
                goal_dist = sim.pathfinder.distance_to_closest_obstacle(goal_position, max_search_radius=2.0)
                ao_geo_dist = geodesic_distance(sim.pathfinder, agent_position, [goal_position])
                og_geo_dist = geodesic_distance(simple_pathfinder, object_position, [goal_position])
                
                og_l2_dist = euclidean_distance(object_position, goal_position)
                og_dist_ratio = og_geo_dist / og_l2_dist

                if og_dist_ratio > 1.2 and goal_dist > 0.1 and ao_geo_dist <100:
                    # print(og_dist_ratio, og_geo_dist, og_l2_dist)
                    break
                
            if oi >= 100: 
                print('cannot find goal position')
                continue

            sim.set_object_motion_type(MotionType.DYNAMIC, object_id)
            sim.set_object_motion_type(MotionType.DYNAMIC, goal_id)
            
            
            sim.set_translation(object_position, object_id)
            sim.set_translation(goal_position, goal_id)
            sim.set_rotation(orientation, object_id)
            sim.set_rotation(orientation, goal_id)
            
            object_position = set_object_on_top_of_surface(sim, object_id)
            goal_position = set_object_on_top_of_surface(sim, goal_id)
            
            if not validate_object_goal_pointnav(sim, simple_pathfinder, agent_position, object_position, goal_position):
                # print("validate pointnav failed ")
                continue
            
            
            sim.set_object_motion_type(MotionType.STATIC, object_id)
            sim.set_object_motion_type(MotionType.STATIC, goal_id)
            
            if object_obstacles:
                sim.recompute_navmesh(
                    sim.pathfinder, 
                    navmesh_settings,
                    include_static_objects=True
                )
            
            if validate_object(
                sim, simple_pathfinder, agent_position, object_position, goal_position, 
                object_positions, goal_positions, 
                dist_threshold=dist_thresh
            ) and validate_again(sim, simple_pathfinder, object_positions, goal_positions):
                break

            
#             if graph_validate(
#                 sim, 
#                 simple_pathfinder,
#                 dist_threshold=dist_thresh
#             ):
# #                 print(
# #                     "added object: "
# #                     + str(object_id)
# #                     + " at: "
# #                     + str(object_position)
# #                 )
#                 break
            
            count += 1
        
        if count < 100:
            object_positions.append(object_position)
            goal_positions.append(goal_position)    
            object_idxs.append(object_id)
            goal_idxs.append(goal_id)
            object_template_idxs.append(object_template_id)
            # print("Success in {}".format(count))
        else:
            sim.remove_object(object_id)
            sim.remove_object(goal_id)
            return object_positions, goal_positions, object_idxs, goal_idxs, object_template_idxs

        if object_obstacles:
            # recompute navmesh so that objects don't overlap with other existing objects. 
            sim.recompute_navmesh(
                sim.pathfinder, 
                navmesh_settings,
                include_static_objects=True
            )
        
    return object_positions, goal_positions, object_idxs, goal_idxs, object_template_idxs

# %%
def build_single_episode(sim, settings, scene_id, num_objects=5, object_obstacles=True):   
    simple_pathfinder = habitat_sim.PathFinder()
    name, ext = os.path.splitext(settings['scene'])
    simple_pathfinder.load_nav_mesh(name + ".navmesh")
    sim.recompute_navmesh(
        simple_pathfinder, navmesh_settings, False
    )

    sim.recompute_navmesh(sim.pathfinder, navmesh_settings, object_obstacles)
    
    episode = 0
    dist_thresh = 3.0

    object_count = num_objects
    episode_attempt_count = 0

    # clear the objects if we are re-running this initializer
    for old_obj_id in sim.get_existing_object_ids()[:]:
        sim.remove_object(old_obj_id)

    start_state, agent_object_id = init_agent(sim)
    sim.recompute_navmesh(sim.pathfinder, navmesh_settings, object_obstacles)

    if num_objects == 5: 
        num_object = 5
    else: 
        num_object = np.random.choice(range(2, object_count + 1))

    object_positions, goal_positions, object_idxs, goal_idxs, object_template_idxs = init_test_scene_new(
        sim, simple_pathfinder, object_templates, navmesh_settings, num_object, dist_thresh, object_obstacles
    )

    result = graph_validate(sim, simple_pathfinder, agent_object_id, dist_thresh)
    
    if result == False or len(object_idxs) == 0:
        print("graph validation failed")
        episode_attempt_count += 1
        if episode_attempt_count % 20 == 0 and episode_attempt_count > 20: 
            print("Reducing object count")
            object_count -= 1
            object_count = max(2, object_count)
        return None , None

    episode_attempt_count = 0

    assert len(object_idxs) == len(goal_idxs)


    episode_dict = init_episode_dict(sim, scene, episode, agent_object_id)
    episode_dict = add_object_details(sim, episode_dict, len(object_idxs), object_idxs, object_template_idxs)
    episode_dict = add_goal_details(sim, episode_dict, len(object_idxs), goal_idxs)
    return episode_dict, agent_object_id

# %%
object_templates = {}
with open('/srv/share3/hagrawal9/project/habitat/habitat-api/data/ycb_object_templates.json') as f:
    object_templates = json.load(f)

# %%
train_df = pd.read_pickle('data/sokoban_gibson_test.pkl')

# %%
scene_id = train_df['id'].tolist()[0]

# %%
scene = 'data/scene_datasets/gibson_train_val/{}.glb'.format(scene_id)

settings['scene'] = scene
print(scene)
cfg = make_cfg(settings)
try:
    if sim is not None:
        sim.close()
except Exception as e:
    pass
sim = habitat_sim.Simulator(cfg)
# Out:
# I1107 11:48:48.376296 17912 simulator.py:168] Loaded navmesh data/scene_datasets/gibson_train_val/Stockertown.navmesh
# data/scene_datasets/gibson_train_val/Stockertown.glb

# %%
def sample_episode(sim, settings, scene_id, num_objects):
    episode, agent_object_id = build_single_episode(sim, settings, scene_id, num_objects=num_objects)

    if episode is None:
        return episode, agent_object_id, None, False
    i = 0
    while (i < 20):
        object_positions = [obj['position'] for obj in episode['objects']]
        goal_positions = [obj['position'] for obj in episode['goals']]
        agent_pos = sim.get_agent(0).get_state().position
        top_down_map = None
#         top_down_map, fow_mask = get_top_down_map_sim(
#             sim, 
#             sim.pathfinder, 
#             object_positions, 
#             goal_positions,
#             navmesh_settings,
#             fog_of_war_mask=None, 
#             ignore_objects=True, 
#             draw_fow=True, 
#             draw_agent=True, 
#             draw_object_start_pos=True,
#             draw_object_final_pos=True
#         )

        res = compute_oracle_pickup_order_sim(sim, sim.pathfinder, agent_pos, object_positions, goal_positions)
        res1 = compute_l2dist_pickup_order_sim(sim, agent_pos, object_positions, goal_positions)
        
        if res['pickup_order'] is None:
            pass
        elif res1['pickup_order_l2dist'] is None:
            pass
        else:
            dist = start_env_episode_distance_sim(sim, sim.pathfinder, agent_pos, object_positions, goal_positions, res['pickup_order'])        
            dist1 = start_env_episode_distance_sim(sim, sim.pathfinder, agent_pos, object_positions, goal_positions, res1['pickup_order_l2dist'])
            print('\r ratio: {:.3f} \tlength: {} \t i:{}'.format(dist/dist1, len(episodes)+1, i), end=" ")
            if (dist/dist1 < 0.95):
                # print(res['pickup_order'], res1['pickup_order_l2dist'])
                return episode, agent_object_id, top_down_map, True
            i+=1
        
        sim.remove_object(agent_object_id)
        start_state, agent_object_id = init_agent(sim)
        # print(agent_pos, i)

    return episode, agent_object_id, top_down_map, False

# %%
episodes = []

# %%
attempt = 0
while(len(episodes) < 50):
    # episode = sample_episode(sim, settings, scene_id, num_objects)
    episode, agent_object_id, tdmap, s = sample_episode(sim, settings, scene_id, num_objects=5)
    
    if s:
        episodes.append(episode)
    else:
        print('\n retrying {} \t attempt:{}'.format(len(episodes), attempt))
    attempt+=1
# Out:
#  ratio: 1.000 	length: 6 	 i:19
#  retrying 5 	 attempt:0
#  ratio: 0.977 	length: 6 	 i:19
#  retrying 5 	 attempt:1
#  ratio: 0.988 	length: 6 	 i:19
#  retrying 5 	 attempt:2
#  ratio: 1.000 	length: 7 	 i:19
#  retrying 6 	 attempt:4
#  ratio: 1.000 	length: 8 	 i:19
#  retrying 7 	 attempt:6
#  ratio: 0.999 	length: 8 	 i:19
#  retrying 7 	 attempt:7
#  ratio: 0.923 	length: 8 	 i:3 graph validation failed
#
#  retrying 8 	 attempt:9
#  ratio: 1.000 	length: 9 	 i:19
#  retrying 8 	 attempt:10
# graph validation failed
#
#  retrying 8 	 attempt:11
#  ratio: 1.000 	length: 11 	 i:19
#  retrying 10 	 attempt:14
#  ratio: 0.981 	length: 13 	 i:19
#  retrying 12 	 attempt:17
#  ratio: 0.977 	length: 13 	 i:19
#  retrying 12 	 attempt:18
#  ratio: 0.997 	length: 13 	 i:19
#  retrying 12 	 attempt:19
#  ratio: 1.000 	length: 13 	 i:19
#  retrying 12 	 attempt:20
#  ratio: 1.000 	length: 13 	 i:19
#  retrying 12 	 attempt:21
#  ratio: 1.010 	length: 13 	 i:19
#  retrying 12 	 attempt:22
#  ratio: 0.994 	length: 13 	 i:19
#  retrying 12 	 attempt:23
#  ratio: 1.000 	length: 13 	 i:19
#  retrying 12 	 attempt:24
#  ratio: 0.974 	length: 14 	 i:19
#  retrying 13 	 attempt:26
#  ratio: 1.000 	length: 15 	 i:19
#  retrying 14 	 attempt:28
#  ratio: 0.951 	length: 15 	 i:19
#  retrying 14 	 attempt:29
#  ratio: 0.986 	length: 15 	 i:19
#  retrying 14 	 attempt:30
#  ratio: 1.000 	length: 16 	 i:19
#  retrying 15 	 attempt:32
#  ratio: 0.994 	length: 16 	 i:19
#  retrying 15 	 attempt:33
#  ratio: 1.000 	length: 17 	 i:19
#  retrying 16 	 attempt:35
#  ratio: 1.000 	length: 17 	 i:19
#  retrying 16 	 attempt:36
#  ratio: 0.972 	length: 17 	 i:19
#  retrying 16 	 attempt:37
#  ratio: 1.000 	length: 17 	 i:19
#  retrying 16 	 attempt:38
#  ratio: 1.000 	length: 18 	 i:19
#  retrying 17 	 attempt:40
#  ratio: 1.011 	length: 20 	 i:19
#  retrying 19 	 attempt:43
#  ratio: 1.000 	length: 22 	 i:19
#  retrying 21 	 attempt:46
#  ratio: 0.933 	length: 22 	 i:5 graph validation failed
#
#  retrying 22 	 attempt:48
#  ratio: 0.984 	length: 24 	 i:19
#  retrying 23 	 attempt:50
#  ratio: 0.942 	length: 28 	 i:1

# %%
files = os.listdir('data/datasets/rearrangement/gibson/v1/test/content/')

# %%
def fix_scene_id(episodes):
    for episode in episodes:
        scene_id = episode['scene_id']
        if '.glb' in scene_id:
            continue
        scene = 'data/scene_datasets/gibson_train_val/{}.glb'.format(scene_id)
        episode['scene_id'] = scene

# %%
def fix_start_pose(episodes):
    for episode in episodes:
        if len(episode['start_position']) == 3:
            print('\r fixed', end=" ")
            continue
        episode['start_position'] = episode['start_position'][0]
        episode['start_rotation'] = episode['start_rotation'][0]

# %%
def fix_episode_ids(episodes):
    episode_id = 0
    for episode in episodes:
        episode['episode_id'] = episode_id
        episode_id += 1

# %%
for file in files:
    print(file)
    dp = os.path.join('data/datasets/rearrangement/gibson/v1/test/content', file)
    with gzip.open(dp, 'rt') as f:
        data = json.load(f)
        
    fix_episode_ids(data['episodes'])
    
    with gzip.open(dp, 'wt') as f:
        json.dump(data, f)
# Out:
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v7_test_n=100_o=5_t=0.9_Howie.json.gz

# %%
data['episodes']
# Out:
# [{'episode_id': 0,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-10.354809761047363,
#    -2.426058292388916,
#    -6.071814060211182],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/077_rubiks_cube.phys_properties.json',
#     'position': [-4.743828773498535, -2.3970887660980225, -5.57540225982666],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-j_cups.phys_properties.json',
#     'position': [0.08619874715805054, -2.3883137702941895, -6.409188747406006],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/012_strawberry.phys_properties.json',
#     'position': [-12.087185859680176, -2.4032208919525146, -6.908590316772461],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/017_orange.phys_properties.json',
#     'position': [-0.7208332419395447,
#      -2.3903822898864746,
#      -1.3115440607070923],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/071_nine_hole_peg_test.phys_properties.json',
#     'position': [1.254563570022583, -2.405719757080078, -6.933296203613281],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-12.560506820678711,
#      -2.3970887660980225,
#      -5.61822509765625],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.43834638595581055,
#      -2.3883137702941895,
#      -0.8391443490982056],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-6.213335990905762, -2.4032208919525146, -4.790555953979492],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [2.607541084289551, -2.3903822898864746, -0.8140396475791931],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.09835019707679749,
#      -2.405719757080078,
#      0.03455168008804321],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 1,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-0.35819458961486816,
#    -2.426058292388916,
#    -2.436628580093384],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/007_tuna_fish_can.phys_properties.json',
#     'position': [-5.117928504943848, -2.4092893600463867, -4.524613380432129],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/003_cracker_box.phys_properties.json',
#     'position': [-15.720834732055664, -2.3193397521972656, -3.072542905807495],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/007_tuna_fish_can.phys_properties.json',
#     'position': [-0.07781241834163666,
#      -2.4092893600463867,
#      -0.9791198968887329],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/071_nine_hole_peg_test.phys_properties.json',
#     'position': [0.006069958209991455,
#      -2.405719757080078,
#      -7.6400065422058105],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/017_orange.phys_properties.json',
#     'position': [1.972063422203064, -2.3903822898864746, -4.320383548736572],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [1.409856915473938,
#      -2.4092893600463867,
#      -1.0217149257659912],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-9.696051597595215, -2.3193397521972656, -1.1997357606887817],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.2965447902679443, -2.4092893600463867, -8.8931884765625],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-2.761751651763916, -2.405719757080078, -5.1542205810546875],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-2.72933030128479, -2.3903822898864746, -2.229118585586548],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 2,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-4.135668754577637,
#    0.17394161224365234,
#    -2.2740252017974854],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/008_pudding_box.phys_properties.json',
#     'position': [-2.8700244426727295,
#      0.19338612258434296,
#      -4.5130438804626465],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-j_cups.phys_properties.json',
#     'position': [-15.638532638549805, 0.2116861194372177, -6.534905433654785],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-i_cups.phys_properties.json',
#     'position': [-4.875795364379883, 0.2117186188697815, -5.619718551635742],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/014_lemon.phys_properties.json',
#     'position': [-16.26226234436035, 0.2004501074552536, -7.341073989868164],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/016_pear.phys_properties.json',
#     'position': [-6.460935115814209, 0.20677311718463898, -4.929443359375],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-14.11900520324707,
#      0.19338612258434296,
#      -6.840273857116699],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-14.206594467163086, 0.2116861194372177, -3.0299949645996094],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.324328422546387, 0.2117186188697815, -7.878437042236328],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-5.910025596618652, 0.2004501074552536, -7.082454681396484],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-4.504260540008545, 0.20677311718463898, -0.7643187046051025],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 3,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-0.8080328106880188,
#    0.17394161224365234,
#    -5.426079750061035],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/025_mug.phys_properties.json',
#     'position': [0.973346471786499, 0.21459311246871948, -5.581736087799072],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/054_softball.phys_properties.json',
#     'position': [-5.2669572830200195, 0.22123710811138153, -6.490694999694824],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/005_tomato_soup_can.phys_properties.json',
#     'position': [-5.3627543449401855, 0.22486910223960876, -5.123964309692383],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/056_tennis_ball.phys_properties.json',
#     'position': [-16.115806579589844,
#      0.20717011392116547,
#      -7.2601823806762695],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/015_peach.phys_properties.json',
#     'position': [-4.0383501052856445,
#      0.20326411724090576,
#      -2.4323370456695557],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-15.516345024108887,
#      0.21459311246871948,
#      -7.842899799346924],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-6.459912300109863, 0.22123710811138153, -0.7815712690353394],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.062570571899414, 0.22486910223960876, -1.039709448814392],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.1074800491333, 0.20717011392116547, -8.063979148864746],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-6.190425395965576, 0.20326411724090576, -4.828808784484863],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 4,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [2.8338749408721924,
#    -2.426058292388916,
#    -2.391181230545044],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/010_potted_meat_can.phys_properties.json',
#     'position': [-12.168624877929688, -2.384286880493164, -6.539012908935547],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/063-b_marbles.phys_properties.json',
#     'position': [2.8507399559020996, -2.4088141918182373, -5.52701473236084],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/024_bowl.phys_properties.json',
#     'position': [1.8226861953735352, -2.3985538482666016, -5.0909576416015625],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/073-f_lego_duplo.phys_properties.json',
#     'position': [-14.129779815673828,
#      -2.4043471813201904,
#      -3.7583863735198975],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/036_wood_block.phys_properties.json',
#     'position': [2.5782864093780518, -2.323056697845459, -1.8941947221755981],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-2.9475202560424805,
#      -2.384286880493164,
#      -4.724046230316162],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-1.174594521522522, -2.4088141918182373, -1.1479840278625488],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.41307538747787476,
#      -2.3985538482666016,
#      -2.5281262397766113],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.627161979675293,
#      -2.4043471813201904,
#      -1.1296637058258057],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-10.499521255493164, -2.323056697845459, -7.285693645477295],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 5,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-8.038020133972168,
#    0.17394161224365234,
#    -2.255269765853882],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/058_golf_ball.phys_properties.json',
#     'position': [-5.301188945770264, 0.19512911140918732, -6.357111930847168],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/004_sugar_box.phys_properties.json',
#     'position': [-16.231306076049805, 0.2619491219520569, -6.769099712371826],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-d_cups.phys_properties.json',
#     'position': [-14.38978385925293, 0.20840661227703094, -2.566941022872925],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/065-f_cups.phys_properties.json',
#     'position': [1.027666449546814, 0.21003061532974243, -5.749849319458008],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/065-b_cups.phys_properties.json',
#     'position': [2.112055778503418, 0.2059241235256195, -6.499469757080078],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-8.025177001953125,
#      0.19512911140918732,
#      -1.7388432025909424],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-3.0107648372650146, 0.2619491219520569, -6.580067157745361],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.718973159790039, 0.20840661227703094, -5.189905166625977],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-14.504853248596191, 0.21003061532974243, -6.709965705871582],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.659797668457031, 0.2059241235256195, -0.942526638507843],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 6,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-15.69865608215332,
#    0.17394161224365234,
#    -7.582201957702637],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/006_mustard_bottle.phys_properties.json',
#     'position': [-14.401515007019043, 0.2695921063423157, -2.7432851791381836],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/009_gelatin_box.phys_properties.json',
#     'position': [-1.8878200054168701, 0.18897861242294312, -4.477167129516602],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/008_pudding_box.phys_properties.json',
#     'position': [-14.88216781616211, 0.19338612258434296, -6.374215602874756],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/063-b_marbles.phys_properties.json',
#     'position': [2.045167922973633, 0.1911856085062027, -6.459715366363525],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/019_pitcher_base.phys_properties.json',
#     'position': [-15.089010238647461, 0.2951350808143616, -7.3953962326049805],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-11.755799293518066,
#      0.2695921063423157,
#      -7.881357669830322],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.2891480922698975, 0.18897861242294312, -4.522121429443359],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-6.762354850769043, 0.19338612258434296, -4.8956618309021],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-13.946086883544922, 0.1911856085062027, -7.101752281188965],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.638738632202148, 0.2951350808143616, -1.6170423030853271],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 7,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [3.424711227416992,
#    -2.426058292388916,
#    -0.05010361596941948],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/057_racquetball.phys_properties.json',
#     'position': [-1.3232322931289673, -2.398271322250366, -6.256700038909912],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-h_cups.phys_properties.json',
#     'position': [0.05293816328048706, -2.388526678085327, -2.026398181915283],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-e_cups.phys_properties.json',
#     'position': [-4.036514759063721, -2.390669345855713, -4.933889865875244],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/012_strawberry.phys_properties.json',
#     'position': [-0.3105378746986389, -2.4032208919525146, -6.560218811035156],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/055_baseball.phys_properties.json',
#     'position': [-5.748966693878174, -2.3897767066955566, -4.451264381408691],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-0.8662660717964172,
#      -2.398271322250366,
#      0.2718468904495239],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [2.198347568511963, -2.388526678085327, -5.903425216674805],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.800459623336792, -2.390669345855713, -7.25446081161499],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-1.0486377477645874, -2.4032208919525146, -2.277724504470825],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.853432655334473, -2.3897767066955566, -6.574248313903809],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 8,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-16.242958068847656,
#    0.17394161224365234,
#    -6.853740215301514],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/065-j_cups.phys_properties.json',
#     'position': [-4.0252790451049805, 0.2116861194372177, -4.868002414703369],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/072-c_toy_airplane.phys_properties.json',
#     'position': [-14.224225997924805, 0.20730260014533997, -6.666675567626953],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-c_cups.phys_properties.json',
#     'position': [-16.10962677001953, 0.20721961557865143, -7.138769149780273],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/063-b_marbles.phys_properties.json',
#     'position': [2.029609441757202, 0.1911856085062027, -7.4967827796936035],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/056_tennis_ball.phys_properties.json',
#     'position': [-14.387481689453125,
#      0.20717011392116547,
#      -2.7564172744750977],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [0.6624946594238281,
#      0.2116861194372177,
#      -4.842618465423584],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-4.736990928649902, 0.20730260014533997, -4.752050876617432],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-15.15596866607666, 0.20721961557865143, -3.474590301513672],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.25843334197998, 0.1911856085062027, -8.011869430541992],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-10.108243942260742,
#      0.20717011392116547,
#      -0.9672632217407227],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 9,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [0.12564386427402496,
#    -2.426058292388916,
#    1.7511012554168701],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/025_mug.phys_properties.json',
#     'position': [-0.6545843482017517, -2.385406732559204, -1.144225835800171],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-g_cups.phys_properties.json',
#     'position': [-15.551410675048828, -2.3890762329101562, -3.620476245880127],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/004_sugar_box.phys_properties.json',
#     'position': [-4.658768653869629, -2.3380508422851562, -5.528057098388672],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/077_rubiks_cube.phys_properties.json',
#     'position': [-5.65048885345459, -2.3970887660980225, -4.850467681884766],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/073-f_lego_duplo.phys_properties.json',
#     'position': [-0.2910838723182678,
#      -2.4043471813201904,
#      -0.1774231344461441],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [3.408238172531128,
#      -2.385406732559204,
#      -4.076498508453369],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-10.187744140625, -2.3890762329101562, -1.2816948890686035],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.525659203529358, -2.3380508422851562, -0.7967027425765991],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-1.3329657316207886, -2.3970887660980225, -2.434544563293457],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-10.48199462890625, -2.4043471813201904, -6.876351356506348],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 10,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [1.8854420185089111,
#    -2.426058292388916,
#    -1.3378984928131104],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/065-b_cups.phys_properties.json',
#     'position': [2.5592331886291504, -2.394075870513916, -2.284769058227539],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/010_potted_meat_can.phys_properties.json',
#     'position': [-15.880156517028809, -2.384286880493164, -3.7261250019073486],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/004_sugar_box.phys_properties.json',
#     'position': [-0.2671167254447937, -2.3380508422851562, 0.5066994428634644],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/055_baseball.phys_properties.json',
#     'position': [-11.075202941894531, -2.3897767066955566, -6.62495756149292],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/056_tennis_ball.phys_properties.json',
#     'position': [-4.472183704376221, -2.3928298950195312, -4.4149298667907715],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-2.4272665977478027,
#      -2.394075870513916,
#      -1.186689853668213],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-1.8242534399032593, -2.384286880493164, -9.143568992614746],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [2.2233359813690186, -2.3380508422851562, -6.848725318908691],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [2.57806396484375, -2.3897767066955566, -5.132571697235107],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.873394012451172, -2.3928298950195312, -6.784584045410156],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 11,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [3.4298579692840576,
#    -2.426058292388916,
#    -0.36981111764907837],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/015_peach.phys_properties.json',
#     'position': [0.21727119386196136, -2.396735906600952, -4.87278938293457],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/005_tomato_soup_can.phys_properties.json',
#     'position': [0.36946505308151245, -2.3751308917999268, -7.463135719299316],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/018_plum.phys_properties.json',
#     'position': [-10.953008651733398, -2.399538278579712, -7.02987003326416],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/065-g_cups.phys_properties.json',
#     'position': [-5.008020401000977, -2.3890762329101562, -5.5861406326293945],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/014_lemon.phys_properties.json',
#     'position': [-0.3095269203186035,
#      -2.399549722671509,
#      -0.08540278673171997],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-10.242527961730957,
#      -2.396735906600952,
#      -5.843151092529297],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.08418160676956177, -2.3751308917999268, 1.123746395111084],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-3.018695831298828, -2.399538278579712, -1.624826431274414],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.116212844848633, -2.3890762329101562, -6.14833402633667],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [3.2232978343963623, -2.399549722671509, -8.586339950561523],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 12,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [2.4630491733551025,
#    -2.426058292388916,
#    -2.9369325637817383],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/073-f_lego_duplo.phys_properties.json',
#     'position': [2.4070611000061035, -2.4043471813201904, -4.464505195617676],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/073-b_lego_duplo.phys_properties.json',
#     'position': [0.25750023126602173, -2.40440034866333, -6.759363174438477],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/063-b_marbles.phys_properties.json',
#     'position': [-1.0983896255493164, -2.4088141918182373, -8.14573860168457],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/057_racquetball.phys_properties.json',
#     'position': [-0.4827651381492615,
#      -2.398271322250366,
#      -0.22834967076778412],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/009_gelatin_box.phys_properties.json',
#     'position': [1.8390377759933472, -2.4110212326049805, -5.848986625671387],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-2.934441089630127,
#      -2.4043471813201904,
#      -1.6775145530700684],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.2997005581855774, -2.40440034866333, -2.7878501415252686],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-7.104333877563477, -2.4088141918182373, -3.929326295852661],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.419387817382812, -2.398271322250366, -6.620060443878174],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.24455200135707855,
#      -2.4110212326049805,
#      0.35787153244018555],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 13,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-2.686889171600342,
#    -2.426058292388916,
#    -4.999131679534912],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/057_racquetball.phys_properties.json',
#     'position': [-0.8032190799713135, -2.398271322250366, -0.9284234046936035],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/002_master_chef_can.phys_properties.json',
#     'position': [-0.7273905873298645, -2.3559699058532715, -8.004199028015137],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/024_bowl.phys_properties.json',
#     'position': [2.8956665992736816, -2.3985538482666016, -1.9797700643539429],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/002_master_chef_can.phys_properties.json',
#     'position': [-0.03192436695098877,
#      -2.3559699058532715,
#      -1.8189363479614258],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/058_golf_ball.phys_properties.json',
#     'position': [3.029536008834839, -2.4048707485198975, -6.898857593536377],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-1.7979930639266968,
#      -2.398271322250366,
#      -7.326163291931152],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.10072733461856842,
#      -2.3559699058532715,
#      -0.11671727895736694],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-6.104024887084961, -2.3985538482666016, -1.50381600856781],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [3.1594886779785156, -2.3559699058532715, -8.550861358642578],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.57189655303955, -2.4048707485198975, -5.627178192138672],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 14,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-10.701557159423828,
#    -2.426058292388916,
#    -5.409158706665039],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/004_sugar_box.phys_properties.json',
#     'position': [-5.529168605804443, -2.3380508422851562, -7.184928894042969],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-h_cups.phys_properties.json',
#     'position': [-0.5052370429039001, -2.388526678085327, -6.562991142272949],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-f_cups.phys_properties.json',
#     'position': [-0.34055453538894653,
#      -2.3899693489074707,
#      -7.860709190368652],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/053_mini_soccer_ball.phys_properties.json',
#     'position': [-5.742727756500244, -2.363264799118042, -4.586281776428223],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/063-b_marbles.phys_properties.json',
#     'position': [-10.739543914794922, -2.4088141918182373, -6.047196388244629],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [1.2416318655014038,
#      -2.3380508422851562,
#      -6.726600646972656],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-1.9839096069335938, -2.388526678085327, -1.1538105010986328],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.16913987696170807, -2.3899693489074707, -1.943388819694519],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.217493057250977, -2.363264799118042, -5.535942554473877],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.707862377166748, -2.4088141918182373, -4.2118706703186035],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 15,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-12.483237266540527,
#    -2.426058292388916,
#    -6.135689735412598],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/061_foam_brick.phys_properties.json',
#     'position': [-9.466662406921387, -2.4004616737365723, -1.5894801616668701],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-d_cups.phys_properties.json',
#     'position': [-0.494109183549881, -2.3915932178497314, -7.3661932945251465],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-f_cups.phys_properties.json',
#     'position': [2.722043752670288, -2.3899693489074707, -5.909749984741211],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/072-a_toy_airplane.phys_properties.json',
#     'position': [-0.040825217962265015,
#      -2.3343393802642822,
#      -8.814061164855957],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/065-f_cups.phys_properties.json',
#     'position': [0.021955281496047974,
#      -2.3899693489074707,
#      -0.09953741729259491],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [3.172882556915283,
#      -2.4004616737365723,
#      -0.6984288692474365],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-4.911585807800293, -2.3915932178497314, -5.929121017456055],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.13029325008392334,
#      -2.3899693489074707,
#      -1.736024022102356],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.8605895042419434, -2.3343393802642822, -2.331836700439453],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [3.6612942218780518, -2.3899693489074707, -2.852259397506714],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 16,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-11.595523834228516,
#    0.17394161224365234,
#    -3.1955981254577637],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/055_baseball.phys_properties.json',
#     'position': [-14.385194778442383,
#      0.21022310853004456,
#      -2.2810235023498535],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/006_mustard_bottle.phys_properties.json',
#     'position': [-14.50820541381836, 0.2695921063423157, -6.5422258377075195],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/013_apple.phys_properties.json',
#     'position': [-3.5173287391662598, 0.2098861038684845, -1.929645299911499],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/065-e_cups.phys_properties.json',
#     'position': [-3.6219642162323, 0.20933061838150024, -5.179261207580566],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/073-f_lego_duplo.phys_properties.json',
#     'position': [-4.569699287414551, 0.19565260410308838, -5.258301258087158],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-11.19244384765625,
#      0.21022310853004456,
#      -8.060714721679688],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.372236251831055, 0.2695921063423157, -1.1803735494613647],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.5867860317230225, 0.2098861038684845, -4.409303188323975],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.864347457885742,
#      0.20933061838150024,
#      -1.2577364444732666],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-5.308498382568359, 0.19565260410308838, -0.7313328385353088],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 17,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-15.214326858520508,
#    0.17394161224365234,
#    -2.6190598011016846],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/002_master_chef_can.phys_properties.json',
#     'position': [-14.929247856140137, 0.24403011798858643, -6.826792240142822],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-d_cups.phys_properties.json',
#     'position': [-5.90372371673584, 0.20840661227703094, -4.880450248718262],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/061_foam_brick.phys_properties.json',
#     'position': [-15.57291030883789, 0.19953811168670654, -7.395567893981934],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/019_pitcher_base.phys_properties.json',
#     'position': [-3.958131790161133, 0.2951350808143616, -5.340641021728516],
#     'rotation': [-0.4999999701976776,
# ...
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/014_lemon.phys_properties.json',
#     'position': [-3.9721627235412598, 0.2004501074552536, -1.2528855800628662],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/016_pear.phys_properties.json',
#     'position': [-15.619199752807617,
#      0.20677311718463898,
#      -6.5647053718566895],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/024_bowl.phys_properties.json',
#     'position': [-2.6107048988342285, 0.20144611597061157, -4.350649833679199],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/065-h_cups.phys_properties.json',
#     'position': [-15.149887084960938,
#      0.21147310733795166,
#      -2.4932548999786377],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-16.44099235534668,
#      0.18686510622501373,
#      -7.858339309692383],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.7866588234901428, 0.2004501074552536, -4.664276123046875],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-10.940905570983887,
#      0.20677311718463898,
#      -7.9282097816467285],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.969292640686035,
#      0.20144611597061157,
#      -0.9530092477798462],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-10.139318466186523,
#      0.21147310733795166,
#      -1.1274816989898682],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 95,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [0.09910011291503906,
#    -2.426058292388916,
#    -6.438717365264893],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/070-a_colored_wood_blocks.phys_properties.json',
#     'position': [-1.3074257373809814, -2.3433687686920166, -8.809225082397461],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-b_cups.phys_properties.json',
#     'position': [-0.09676700830459595,
#      -2.394075870513916,
#      -2.2297871112823486],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/005_tomato_soup_can.phys_properties.json',
#     'position': [-1.2423948049545288, -2.3751308917999268, -6.079647541046143],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/012_strawberry.phys_properties.json',
#     'position': [-0.2077305018901825, -2.4032208919525146, -8.2521390914917],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/010_potted_meat_can.phys_properties.json',
#     'position': [-0.7691054940223694, -2.384286880493164, -0.5713342428207397],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-12.662708282470703,
#      -2.3433687686920166,
#      -6.169061660766602],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.2676492929458618, -2.394075870513916, -6.845286846160889],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.128742218017578, -2.3751308917999268, -7.375738143920898],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-4.980971336364746, -2.4032208919525146, -6.3250322341918945],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [3.347973108291626, -2.384286880493164, -4.774938583374023],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 96,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [0.5088969469070435,
#    -2.426058292388916,
#    -2.805678129196167],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/058_golf_ball.phys_properties.json',
#     'position': [-0.615919828414917, -2.4048707485198975, -6.290732383728027],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-g_cups.phys_properties.json',
#     'position': [-15.771602630615234, -2.3890762329101562, -4.547187805175781],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-h_cups.phys_properties.json',
#     'position': [-0.4830966591835022, -2.388526678085327, -2.105668067932129],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/009_gelatin_box.phys_properties.json',
#     'position': [-0.45424777269363403,
#      -2.4110212326049805,
#      -7.404216766357422],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/063-b_marbles.phys_properties.json',
#     'position': [-3.8346548080444336, -2.4088141918182373, -4.960937976837158],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-11.531895637512207,
#      -2.4048707485198975,
#      -5.710433483123779],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.842119216918945, -2.3890762329101562, -7.111744403839111],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [2.7759997844696045, -2.388526678085327, -2.289138078689575],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.3733575642108917, -2.4110212326049805, 0.42894500494003296],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.4818509817123413, -2.4088141918182373, -0.954338788986206],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 97,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [2.814645767211914,
#    -2.426058292388916,
#    -0.7996149659156799],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/065-e_cups.phys_properties.json',
#     'position': [-12.17605972290039, -2.390669345855713, -5.345020294189453],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/065-i_cups.phys_properties.json',
#     'position': [-0.5083021521568298,
#      -2.3882813453674316,
#      -0.5912743210792542],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/008_pudding_box.phys_properties.json',
#     'position': [-5.076025009155273, -2.406613826751709, -5.60787296295166],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/025_mug.phys_properties.json',
#     'position': [-1.4370858669281006, -2.385406732559204, -6.310606479644775],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/065-i_cups.phys_properties.json',
#     'position': [1.8111679553985596, -2.3882813453674316, -8.656732559204102],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-1.5992258787155151,
#      -2.390669345855713,
#      -2.7745213508605957],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [2.827820301055908, -2.3882813453674316, -5.098601818084717],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-1.8518264293670654, -2.406613826751709, -7.829340934753418],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.3739413321018219, -2.385406732559204, -0.6067808270454407],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-10.294333457946777, -2.3882813453674316, -5.684268474578857],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 98,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [1.8286004066467285,
#    -2.426058292388916,
#    -2.247567892074585],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/003_cracker_box.phys_properties.json',
#     'position': [-3.575009346008301, -2.3193397521972656, -4.325613975524902],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/012_strawberry.phys_properties.json',
#     'position': [-0.581508994102478, -2.4032208919525146, -0.527570903301239],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-c_cups.phys_properties.json',
#     'position': [2.47055721282959, -2.392780303955078, -4.9737701416015625],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/065-h_cups.phys_properties.json',
#     'position': [3.0018389225006104, -2.388526678085327, -1.3124816417694092],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/017_orange.phys_properties.json',
#     'position': [-15.441865921020508, -2.3903822898864746, -4.449182987213135],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-10.567977905273438,
#      -2.3193397521972656,
#      -5.534926891326904],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [2.5761191844940186, -2.4032208919525146, -6.1534833908081055],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.5269445776939392, -2.392780303955078, 0.6261436343193054],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-11.725320816040039, -2.388526678085327, -6.714829921722412],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.579000473022461, -2.3903822898864746, -7.274769306182861],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]},
#  {'episode_id': 99,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Hallettsville.glb',
#   'start_position': [-7.872661113739014,
#    -2.426058292388916,
#    -0.8105123043060303],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/025_mug.phys_properties.json',
#     'position': [0.33889347314834595, -2.385406732559204, -6.742875099182129],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/061_foam_brick.phys_properties.json',
#     'position': [-0.4771895110607147, -2.4004616737365723, -8.448249816894531],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/019_pitcher_base.phys_properties.json',
#     'position': [-1.2565641403198242,
#      -2.3048648834228516,
#      -1.1244391202926636],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/070-b_colored_wood_blocks.phys_properties.json',
#     'position': [-15.172019958496094, -2.413134813308716, -4.06300163269043],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/003_cracker_box.phys_properties.json',
#     'position': [-11.687429428100586, -2.3193397521972656, -6.030168533325195],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-10.933188438415527,
#      -2.385406732559204,
#      -5.617005348205566],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-5.445638179779053, -2.4004616737365723, -5.523919105529785],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.8877946138381958, -2.3048648834228516, -7.510847091674805],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-12.092243194580078, -2.413134813308716, -6.929473876953125],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.8431587219238281, -2.3193397521972656, 0.5138300657272339],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'pickup_order': [3, 2, 4, 5, 1],
#   'pickup_order_l2dist': [1, 3, 2, 5, 4]}]
