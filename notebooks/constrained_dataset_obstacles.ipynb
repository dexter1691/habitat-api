# %%
import gzip
import json
import os
import sys
from typing import List
from matplotlib import pyplot as plt
import argparse
import magnum as mn
import numpy as np
import pandas as pd
import networkx


import habitat_sim
from habitat_sim.physics import MotionType

from habitat.datasets.rearrangement.rearrangement_dataset import RearrangementDatasetV0
from habitat.tasks.rearrangement.rearrangement_task import RearrangementEpisode
from rearrangement.utils.geometry import geodesic_distance

# %%
cd '/srv/flash1/hagrawal9/project/habitat/habitat-api/'
# Out:
# /coc/testnvme/hagrawal9/project/habitat/habitat-api

# %%
# %load_ext autoreload
# %autoreload 2

from rearrangement.utils.dataset import make_cfg, navmesh_settings, init_agent, init_episode_dict, add_goal_details, add_object_details, set_object_on_top_of_surface, settings
from rearrangement.utils.dataset import validate_again, validate_object, graph_validate, euclidean_distance, validate_object_goal_pointnav
from rearrangement.utils.visualization import get_top_down_map_sim
from rearrangement.utils.planner import compute_oracle_pickup_order_sim, compute_l2dist_pickup_order_sim, start_env_episode_distance_sim

# %%
def init_test_scene_new(sim, simple_pathfinder, object_templates, navmesh_settings, num_objects, dist_thresh=5.0, object_obstacles=True):    
    object_positions = []
    goal_positions = []
    object_idxs = []
    goal_idxs = []
    object_template_idxs = []
    
    obj_attr_mgr = sim.get_object_template_manager()
    agent_position = sim.agents[0].scene_node.translation
    
    sim.recompute_navmesh(
        sim.pathfinder, 
        navmesh_settings,
        include_static_objects=object_obstacles
    )
    
    for obj_id in range(num_objects):
        count = 0
        
        object_template_id = np.random.choice(list(object_templates.keys()))
        object_handle = obj_attr_mgr.get_file_template_handles(object_template_id)[0]
        rotation_x = mn.Quaternion.rotation(mn.Deg(-90), mn.Vector3(1.0, 0, 0))
        rotation_y = mn.Quaternion.rotation(mn.Deg(90), mn.Vector3(0.0, 1.0, 0))
        rotation_z = mn.Quaternion.rotation(mn.Deg(0), mn.Vector3(0.0, 0, 1.0))
        # rotation_x1 = mn.Quaternion.rotation(mn.Deg(-45), mn.Vector3(1.0, 0, 0))
        orientation = rotation_z * rotation_y * rotation_x

        object_id = sim.add_object_by_handle(object_handle)
        goal_id = sim.add_object_by_handle(object_handle)

        
        while count < 100:
            
            for oi in range(100):
                object_position = sim.pathfinder.get_random_navigable_point()
                # object_position[1] = agent_position[1]
                # set_object_on_top_of_surface(sim, object_id)
                
                object_dist = sim.pathfinder.distance_to_closest_obstacle(object_position, max_search_radius=2.0)
                ao_geo_dist = geodesic_distance(sim.pathfinder, agent_position, [object_position])
                
                if object_dist > 0.5 and ao_geo_dist < 100:
                    break

            if  oi >= 100: 
                continue 

             
            for oi in range(100):
                goal_position = sim.pathfinder.get_random_navigable_point()
                # goal_position[1] = agent_position[1]
                # set_object_on_top_of_surface(sim, goal_id)
                
                goal_dist = sim.pathfinder.distance_to_closest_obstacle(goal_position, max_search_radius=2.0)
                ao_geo_dist = geodesic_distance(sim.pathfinder, agent_position, [goal_position])
                og_geo_dist = geodesic_distance(simple_pathfinder, object_position, [goal_position])
                
                og_l2_dist = euclidean_distance(object_position, goal_position)
                og_dist_ratio = og_geo_dist / og_l2_dist

                if og_dist_ratio > 1.2 and goal_dist > 0.1 and ao_geo_dist <100:
                    # print(og_dist_ratio, og_geo_dist, og_l2_dist)
                    break
                
            if oi >= 100: 
                print('cannot find goal position')
                continue

            sim.set_object_motion_type(MotionType.DYNAMIC, object_id)
            sim.set_object_motion_type(MotionType.DYNAMIC, goal_id)
            
            
            sim.set_translation(object_position, object_id)
            sim.set_translation(goal_position, goal_id)
            sim.set_rotation(orientation, object_id)
            sim.set_rotation(orientation, goal_id)
            
            object_position = set_object_on_top_of_surface(sim, object_id)
            goal_position = set_object_on_top_of_surface(sim, goal_id)
            
            if not validate_object_goal_pointnav(sim, simple_pathfinder, agent_position, object_position, goal_position):
                # print("validate pointnav failed ")
                continue
            
            
            sim.set_object_motion_type(MotionType.STATIC, object_id)
            sim.set_object_motion_type(MotionType.STATIC, goal_id)
            
            if object_obstacles:
                sim.recompute_navmesh(
                    sim.pathfinder, 
                    navmesh_settings,
                    include_static_objects=True
                )
            
            if validate_object(
                sim, simple_pathfinder, agent_position, object_position, goal_position, 
                object_positions, goal_positions, 
                dist_threshold=dist_thresh
            ) and validate_again(sim, simple_pathfinder, object_positions, goal_positions):
                break

            
#             if graph_validate(
#                 sim, 
#                 simple_pathfinder,
#                 dist_threshold=dist_thresh
#             ):
# #                 print(
# #                     "added object: "
# #                     + str(object_id)
# #                     + " at: "
# #                     + str(object_position)
# #                 )
#                 break
            
            count += 1
        
        if count < 100:
            object_positions.append(object_position)
            goal_positions.append(goal_position)    
            object_idxs.append(object_id)
            goal_idxs.append(goal_id)
            object_template_idxs.append(object_template_id)
            # print("Success in {}".format(count))
        else:
            sim.remove_object(object_id)
            sim.remove_object(goal_id)
            return object_positions, goal_positions, object_idxs, goal_idxs, object_template_idxs

        if object_obstacles:
            # recompute navmesh so that objects don't overlap with other existing objects. 
            sim.recompute_navmesh(
                sim.pathfinder, 
                navmesh_settings,
                include_static_objects=True
            )
        
    return object_positions, goal_positions, object_idxs, goal_idxs, object_template_idxs

# %%
def build_single_episode(sim, settings, scene_id, num_objects=5, object_obstacles=True):   
    simple_pathfinder = habitat_sim.PathFinder()
    name, ext = os.path.splitext(settings['scene'])
    simple_pathfinder.load_nav_mesh(name + ".navmesh")
    sim.recompute_navmesh(
        simple_pathfinder, navmesh_settings, False
    )

    sim.recompute_navmesh(sim.pathfinder, navmesh_settings, object_obstacles)
    
    episode = 0
    dist_thresh = 3.0

    object_count = num_objects
    episode_attempt_count = 0

    # clear the objects if we are re-running this initializer
    for old_obj_id in sim.get_existing_object_ids()[:]:
        sim.remove_object(old_obj_id)

    start_state, agent_object_id = init_agent(sim)
    sim.recompute_navmesh(sim.pathfinder, navmesh_settings, object_obstacles)

    if num_objects == 5: 
        num_object = 5
    else: 
        num_object = np.random.choice(range(2, object_count + 1))

    object_positions, goal_positions, object_idxs, goal_idxs, object_template_idxs = init_test_scene_new(
        sim, simple_pathfinder, object_templates, navmesh_settings, num_object, dist_thresh, object_obstacles
    )

    result = graph_validate(sim, simple_pathfinder, agent_object_id, dist_thresh)
    
    if result == False or len(object_idxs) == 0:
        print("graph validation failed")
        episode_attempt_count += 1
        if episode_attempt_count % 20 == 0 and episode_attempt_count > 20: 
            print("Reducing object count")
            object_count -= 1
            object_count = max(2, object_count)
        return None , None

    episode_attempt_count = 0

    assert len(object_idxs) == len(goal_idxs)


    episode_dict = init_episode_dict(sim, scene, episode, agent_object_id)
    episode_dict = add_object_details(sim, episode_dict, len(object_idxs), object_idxs, object_template_idxs)
    episode_dict = add_goal_details(sim, episode_dict, len(object_idxs), goal_idxs)
    return episode_dict, agent_object_id

# %%
object_templates = {}
with open('/srv/share3/hagrawal9/project/habitat/habitat-api/data/ycb_object_templates.json') as f:
    object_templates = json.load(f)

# %%
train_df = pd.read_pickle('data/sokoban_gibson_test.pkl')

# %%
scene_id = train_df['id'].tolist()[0]

# %%
scene = 'data/scene_datasets/gibson_train_val/{}.glb'.format(scene_id)

settings['scene'] = scene
print(scene)
cfg = make_cfg(settings)
try:
    if sim is not None:
        sim.close()
except Exception as e:
    pass
sim = habitat_sim.Simulator(cfg)
# Out:
# I1107 11:48:48.376296 17912 simulator.py:168] Loaded navmesh data/scene_datasets/gibson_train_val/Stockertown.navmesh
# data/scene_datasets/gibson_train_val/Stockertown.glb

# %%
def sample_episode(sim, settings, scene_id, num_objects):
    episode, agent_object_id = build_single_episode(sim, settings, scene_id, num_objects=num_objects)

    if episode is None:
        return episode, agent_object_id, None, False
    i = 0
    while (i < 20):
        object_positions = [obj['position'] for obj in episode['objects']]
        goal_positions = [obj['position'] for obj in episode['goals']]
        agent_pos = sim.get_agent(0).get_state().position
        top_down_map = None
#         top_down_map, fow_mask = get_top_down_map_sim(
#             sim, 
#             sim.pathfinder, 
#             object_positions, 
#             goal_positions,
#             navmesh_settings,
#             fog_of_war_mask=None, 
#             ignore_objects=True, 
#             draw_fow=True, 
#             draw_agent=True, 
#             draw_object_start_pos=True,
#             draw_object_final_pos=True
#         )

        res = compute_oracle_pickup_order_sim(sim, sim.pathfinder, agent_pos, object_positions, goal_positions)
        res1 = compute_l2dist_pickup_order_sim(sim, agent_pos, object_positions, goal_positions)
        
        if res['pickup_order'] is None:
            pass
        elif res1['pickup_order_l2dist'] is None:
            pass
        else:
            dist = start_env_episode_distance_sim(sim, sim.pathfinder, agent_pos, object_positions, goal_positions, res['pickup_order'])        
            dist1 = start_env_episode_distance_sim(sim, sim.pathfinder, agent_pos, object_positions, goal_positions, res1['pickup_order_l2dist'])
            print('\r ratio: {:.3f} \tlength: {} \t i:{}'.format(dist/dist1, len(episodes)+1, i), end=" ")
            if (dist/dist1 < 0.95):
                # print(res['pickup_order'], res1['pickup_order_l2dist'])
                return episode, agent_object_id, top_down_map, True
            i+=1
        
        sim.remove_object(agent_object_id)
        start_state, agent_object_id = init_agent(sim)
        # print(agent_pos, i)

    return episode, agent_object_id, top_down_map, False

# %%
episodes = []

# %%
attempt = 0
while(len(episodes) < 50):
    # episode = sample_episode(sim, settings, scene_id, num_objects)
    episode, agent_object_id, tdmap, s = sample_episode(sim, settings, scene_id, num_objects=5)
    
    if s:
        episodes.append(episode)
    else:
        print('\n retrying {} \t attempt:{}'.format(len(episodes), attempt))
    attempt+=1

# %%
files = os.listdir('data/datasets/rearrangement/gibson/v1/test/temp/')

# %%
def fix_scene_id(episodes):
    for episode in episodes:
        scene_id = episode['scene_id']
        if '.glb' in scene_id:
            continue
        scene = 'data/scene_datasets/gibson_train_val/{}.glb'.format(scene_id)
        episode['scene_id'] = scene

# %%
def fix_start_pose(episodes):
    for episode in episodes:
        if len(episode['start_position']) == 3:
            print('\r fixed', end=" ")
            continue
        episode['start_position'] = episode['start_position'][0]
        episode['start_rotation'] = episode['start_rotation'][0]

# %%
def fix_episode_ids(episodes):
    episode_id = 0
    for episode in episodes:
        episode['episode_id'] = episode_id
        episode_id += 1

# %%
for file in files:
    if 'v8' not in file:
        continue
    
    print(file)
    
    dp = os.path.join('data/datasets/rearrangement/gibson/v1/test/temp', file)
    with gzip.open(dp, 'rt') as f:
        data = json.load(f)
        
#     fix_episode_ids(data['episodes'])
    
#     with gzip.open(dp, 'wt') as f:
#         json.dump(data, f)
# Out:
# rearrangement_hard_v8_test_n=51_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=16_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=20_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=32_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=25_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=17_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=15_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=33_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=26_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=18_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=71_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=30_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=32_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=23_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=14_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=36_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=16_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=65_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=22_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=34_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=34_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=45_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=31_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=25_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=16_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=39_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=24_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=26_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=27_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=19_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=36_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=37_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=24_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=13_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=17_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=28_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=59_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=12_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=30_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=43_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=12_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=21_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=24_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=42_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v8_test_n=38_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=41_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=28_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=26_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=18_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=67_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=20_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=58_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=13_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=53_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=20_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=52_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=22_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=24_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=50_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=56_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=14_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=24_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=57_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=70_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=22_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=73_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=22_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=15_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=64_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=23_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=63_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=38_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=44_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=46_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=30_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=47_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=28_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=50_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=51_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=40_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=29_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=74_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=18_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=17_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=12_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=64_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=40_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=19_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=41_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=18_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=45_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=26_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=15_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=52_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=16_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=44_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=60_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=16_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=19_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=39_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=61_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=72_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=38_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=14_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=70_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=12_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=12_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=29_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=18_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=39_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=28_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=66_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=55_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=32_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=46_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=29_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=54_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=27_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=21_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=53_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=20_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=19_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=21_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=73_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=30_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=13_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=31_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=67_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=68_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=35_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=25_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=33_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=15_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=14_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=47_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=49_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=25_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=48_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=35_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=23_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=34_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=25_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=24_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=59_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=31_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=58_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=13_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=76_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=19_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=53_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v8_test_n=52_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=43_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=42_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=66_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=14_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=17_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=14_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=62_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=13_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=46_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=56_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=22_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=12_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=47_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=56_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=17_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=42_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=36_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=57_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=15_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=62_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=72_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=16_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=23_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=23_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=22_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=57_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=9_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=23_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=43_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=26_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=16_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=17_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=37_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=37_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=33_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=63_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=32_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=17_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=20_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=36_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=37_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=27_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=13_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=12_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=18_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=26_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=33_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=27_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=30_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=69_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=22_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=31_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=21_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=15_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=5_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=55_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=35_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=14_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=35_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=33_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=41_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=15_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=36_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=20_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=15_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=31_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=61_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=21_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=30_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=25_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=26_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=69_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=24_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v8_test_n=59_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=13_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=49_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=58_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=10_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=49_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=29_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=11_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=48_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=35_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=32_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=34_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=21_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=12_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=13_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=65_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=68_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=40_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=23_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Silerton.json.gz
# rearrangement_hard_v8_test_n=19_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=41_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=18_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=48_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=50_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=28_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=51_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=25_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=27_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Southfield.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=75_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=27_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=29_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=16_o=5_t=0.9_Spencerville.json.gz
# rearrangement_hard_v8_test_n=8_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=71_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=21_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=28_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=74_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=29_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=3_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=20_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=55_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=1_o=5_t=0.9_Starks.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=54_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=7_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=2_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=54_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=34_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=45_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=40_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=44_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=6_o=5_t=0.9_Cokeville.json.gz
# rearrangement_hard_v8_test_n=14_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=60_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=39_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=61_o=5_t=0.9_Wells.json.gz
# rearrangement_hard_v8_test_n=17_o=5_t=0.9_Sands.json.gz
# rearrangement_hard_v8_test_n=38_o=5_t=0.9_Howie.json.gz
# rearrangement_hard_v8_test_n=19_o=5_t=0.9_Stockertown.json.gz
# rearrangement_hard_v8_test_n=60_o=5_t=0.9_Sagerton.json.gz
# rearrangement_hard_v8_test_n=4_o=5_t=0.9_Stockertown.json.gz

# %%
data['episodes']
# Out:
# [{'episode_id': 0,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Stockertown.glb',
#   'start_position': [-4.140114784240723,
#    0.10475540161132812,
#    5.742221832275391],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/036_wood_block.phys_properties.json',
#     'position': [-1.9938462972640991, 0.2077568769454956, 4.152127265930176],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/006_mustard_bottle.phys_properties.json',
#     'position': [-3.9299473762512207, 0.20040589570999146, 14.349567413330078],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/053_mini_soccer_ball.phys_properties.json',
#     'position': [-2.4787464141845703, 0.16754889488220215, 6.97102165222168],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/070-b_colored_wood_blocks.phys_properties.json',
#     'position': [0.022112548351287842,
#      0.11767890304327011,
#      0.061302050948143005],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/012_strawberry.phys_properties.json',
#     'position': [-7.58837890625, 0.12759290635585785, 4.1930742263793945],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-2.647691249847412,
#      0.2077568769454956,
#      13.258441925048828],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.666104793548584, 0.20040589570999146, 1.3729004859924316],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-3.5105934143066406, 0.16754889488220215, 1.411585807800293],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-10.778780937194824, 0.11767890304327011, 0.1789313554763794],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [0.9612061381340027, 0.12759290635585785, 8.52607250213623],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}]},
#  {'episode_id': 1,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Stockertown.glb',
#   'start_position': [-4.872674942016602,
#    0.10475540161132812,
#    7.191624164581299],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/053_mini_soccer_ball.phys_properties.json',
#     'position': [-2.157968044281006, 0.16754889488220215, 14.765917778015137],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/061_foam_brick.phys_properties.json',
#     'position': [-9.495024681091309, 0.13035190105438232, 0.9443241953849792],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/007_tuna_fish_can.phys_properties.json',
#     'position': [-2.00290846824646, 0.12152440845966339, 6.7044267654418945],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/065-e_cups.phys_properties.json',
#     'position': [-3.290912628173828, 0.14014440774917603, 6.152909278869629],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/065-d_cups.phys_properties.json',
#     'position': [-11.070964813232422, 0.13922040164470673, 9.20496654510498],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-3.5632271766662598,
#      0.16754889488220215,
#      1.5807870626449585],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-6.120116233825684, 0.13035190105438232, 3.602504253387451],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-5.7590012550354, 0.12152440845966339, 13.886616706848145],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.347042441368103, 0.14014440774917603, 7.554368019104004],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-3.4021458625793457, 0.13922040164470673, 7.469733238220215],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}]},
#  {'episode_id': 2,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Stockertown.glb',
#   'start_position': [-0.42403286695480347,
#    0.10475540161132812,
#    4.592257022857666],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/015_peach.phys_properties.json',
#     'position': [-2.9772863388061523, 0.13407790660858154, 3.8925037384033203],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/056_tennis_ball.phys_properties.json',
#     'position': [1.2893143892288208, 0.13798390328884125, 7.868048191070557],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/065-c_cups.phys_properties.json',
#     'position': [-2.278836727142334, 0.1380334049463272, 14.466680526733398],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/054_softball.phys_properties.json',
#     'position': [-11.563960075378418, 0.1520508974790573, 7.264584541320801],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/002_master_chef_can.phys_properties.json',
#     'position': [-4.554267406463623, 0.1748439073562622, 5.272126197814941],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-1.7232919931411743,
#      0.13407790660858154,
#      -0.12533800303936005],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-5.974524021148682, 0.13798390328884125, 9.913844108581543],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [1.3664093017578125, 0.1380334049463272, 5.8282952308654785],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-3.9245526790618896, 0.1520508974790573, 14.85324478149414],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.33651596307754517, 0.1748439073562622, 14.5316743850708],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}]},
#  {'episode_id': 3,
#   'scene_id': 'data/scene_datasets/gibson_train_val/Stockertown.glb',
#   'start_position': [-10.355377197265625,
#    0.10475540161132812,
#    8.387028694152832],
#   'start_rotation': [0.0, 0.0, 0.0, 1.0],
#   'info': {},
#   'objects': [{'object_id': 0,
#     'object_handle': 'data/ycb/003_cracker_box.phys_properties.json',
#     'position': [-0.4517289400100708,
#      0.21147388219833374,
#      -0.34917259216308594],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 1,
#     'object_handle': 'data/ycb/007_tuna_fish_can.phys_properties.json',
#     'position': [-1.1412378549575806, 0.12152440845966339, 6.674278736114502],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 2,
#     'object_handle': 'data/ycb/016_pear.phys_properties.json',
#     'position': [3.0949463844299316, 0.13758690655231476, 0.6530497074127197],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 3,
#     'object_handle': 'data/ycb/036_wood_block.phys_properties.json',
#     'position': [-6.115303993225098, 0.2077568769454956, 15.582429885864258],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'object_id': 4,
#     'object_handle': 'data/ycb/014_lemon.phys_properties.json',
#     'position': [-3.8762810230255127, 0.13126389682292938, 13.527443885803223],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}],
#   'goals': [{'position': [-1.5600038766860962,
#      0.21147388219833374,
#      11.464921951293945],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-0.1900639533996582, 0.12152440845966339, 13.03167724609375],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [-4.700624942779541, 0.13758690655231476, 15.016969680786133],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [3.7019710540771484, 0.2077568769454956, 1.786585807800293],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]},
#    {'position': [2.4681830406188965, 0.13126389682292938, 7.157526016235352],
#     'rotation': [-0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776,
#      0.4999999701976776]}]}]
